# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (20.0, 15.0)

# %%
rawpoints = []
conf      = "scala-native-0.4.3-2.12"
bench     = "manyProcess.ManyProcessBenchmark"
run       = 1
with open("../results/{}/{}/{}".format(conf, bench, run)) as data:
    for line in data.readlines():
        rawpoints.append(float(line)/1000000)
raw = np.array(rawpoints)
filtered = []
pmax = np.percentile(raw, 99)
for point in rawpoints:
    if point < pmax:
        filtered.append(point)
y = np.array(filtered)

# %%
len(y)
# Out:
# 49

# %%
#plt.axis([0, len(y), 0.5, 5])
plt.plot(y)

# %%
plt.hist(y[:200], bins = 10)
# Out:
# (array([20., 11.,  6.,  8.,  0.,  1.,  1.,  1.,  0.,  1.]),
#  array([182.672261 , 201.2970018, 219.9217426, 238.5464834, 257.1712242,
#         275.795965 , 294.4207058, 313.0454466, 331.6701874, 350.2949282,
#         368.919669 ]),
#  <BarContainer object of 10 artists>)

# %%
percentiles = np.arange(0, 100)
percvalue = np.array([np.percentile(y[:500], perc) for perc in percentiles])
plt.plot(percentiles, percvalue)

# %%
np.percentile(y, 5)
# Out:
# 184.9339268

# %%
np.percentile(y, 50)
# Out:
# 206.389907

# %%
np.percentile(y, 95)
# Out:
# 295.66148839999994

# %%
np.mean(y)
# Out:
# 218.57335753061224

# %%
y.std()
# Out:
# 37.31406857771337
