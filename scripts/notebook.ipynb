# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (20.0, 15.0)

# %%
rawpoints = []
conf      = "scala-native-0.4.3-2.12-default"
bench     = "rep.RepBenchmark"
run       = 1
with open("../results/{}/{}/{}".format(conf, bench, run)) as data:
    for line in data.readlines():
        rawpoints.append(float(line)/1000000)
raw = np.array(rawpoints)
filtered = []
pmax = np.percentile(raw, 99)
for point in rawpoints:
    if point < pmax:
        filtered.append(point)
y = np.array(filtered)

# %%
len(y)
# Out:
# 495

# %%
#plt.axis([0, len(y), 0.5, 5])
plt.plot(y)

# %%
plt.hist(y[:200], bins = 10)
# Out:
# (array([118.,  21.,  13.,  17.,  11.,   6.,   1.,   5.,   3.,   5.]),
#  array([119.01914  , 124.2466579, 129.4741758, 134.7016937, 139.9292116,
#         145.1567295, 150.3842474, 155.6117653, 160.8392832, 166.0668011,
#         171.294319 ]),
#  <BarContainer object of 10 artists>)

# %%
percentiles = np.arange(0, 100)
percvalue = np.array([np.percentile(y[:500], perc) for perc in percentiles])
plt.plot(percentiles, percvalue)

# %%
np.percentile(y, 5)
# Out:
# 120.06610280000001

# %%
np.percentile(y, 50)
# Out:
# 122.889355

# %%
np.percentile(y, 95)
# Out:
# 155.37883859999997

# %%
np.mean(y)
# Out:
# 128.3166805292929

# %%
y.std()
# Out:
# 11.423119786214173
